# %% [markdown]
# <a href="https://colab.research.google.com/github/ncc-chandni/ML_Basics/blob/main/Decision_Tree_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data = pd.read_csv("/titanic.csv")

# %%
print(data.head())
print(data.isna().sum())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
data["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
inputs = data.drop(["PassengerId", "Name", "Ticket", "Cabin", "Embarked", "Survived","SibSp","Parch"], axis= 'columns')
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500

# %%
target = data.Survived

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
inputs['sex_'] = le.fit_transform(inputs["Sex"])
inputs
# Out:
#      Pclass     Sex   Age     Fare  sex_
# 0         3    male  22.0   7.2500     1
# 1         1  female  38.0  71.2833     0
# 2         3  female  26.0   7.9250     0
# 3         1  female  35.0  53.1000     0
# 4         3    male  35.0   8.0500     1
# ..      ...     ...   ...      ...   ...
# 886       2    male  27.0  13.0000     1
# 887       1  female  19.0  30.0000     0
# 888       3  female   NaN  23.4500     0
# 889       1    male  26.0  30.0000     1
# 890       3    male  32.0   7.7500     1
#
# [891 rows x 5 columns]

# %%
inputs = inputs.drop(["Sex"], axis = 'columns')
inputs
# Out:
#      Pclass   Age     Fare  sex_
# 0         3  22.0   7.2500     1
# 1         1  38.0  71.2833     0
# 2         3  26.0   7.9250     0
# 3         1  35.0  53.1000     0
# 4         3  35.0   8.0500     1
# ..      ...   ...      ...   ...
# 886       2  27.0  13.0000     1
# 887       1  19.0  30.0000     0
# 888       3   NaN  23.4500     0
# 889       1  26.0  30.0000     1
# 890       3  32.0   7.7500     1
#
# [891 rows x 4 columns]

# %%
inputs['Age'].fillna(int(inputs['Age'].mean()), inplace=True)

# %%
inputs.isna().sum()
# Out:
# Pclass    0
# Age       0
# Fare      0
# sex_      0
# dtype: int64

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.2)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 712
# 179

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.7597765363128491
